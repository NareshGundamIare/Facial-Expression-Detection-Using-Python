# %% [markdown]
# <a href="https://colab.research.google.com/github/NareshGundamIare/Facial-Expression-Detection-Using-Python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 30.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 8.4 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=9142aa6e157aa7b111d1df0f1fab9ad7dd1edc5d8befca5f77afb97104d7f6eb
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
from google.colab import drive
drive.mount('/content/drive')
img=cv2.imread('/content/drive/MyDrive/expression ref.jpeg')
plt.imshow(img[:,:,::-1])
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
result=DeepFace.analyze(img,actions=['emotion'])
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 20.8MB/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]

# %%
print(result)
# Out:
# [{'emotion': {'angry': 0.011115265208991294, 'disgust': 2.3131270614955268e-10, 'fear': 0.07893957886447563, 'happy': 8.631315543494756, 'sad': 0.0178293842173543, 'surprise': 91.26042231793137, 'neutral': 0.00037052261762697477}, 'dominant_emotion': 'surprise', 'region': {'x': 28, 'y': 28, 'w': 116, 'h': 116}}]
